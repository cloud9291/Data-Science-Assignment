# %%
import pandas as pd
import matplotlib.pyplot as plt
birds = pd.read_csv('bird-species-tiny.csv')
birds.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                       filepaths            labels  \
# 0          3006        3006  train/BANDED BROADBILL/001.jpg  BANDED BROADBILL
# 1          3007        3007  train/BANDED BROADBILL/002.jpg  BANDED BROADBILL
# 2          3008        3008  train/BANDED BROADBILL/003.jpg  BANDED BROADBILL
# 3          3009        3009  train/BANDED BROADBILL/004.jpg  BANDED BROADBILL
# 4          3010        3010  train/BANDED BROADBILL/005.jpg  BANDED BROADBILL
#
#   data set
# 0    train
# 1    train
# 2    train
# 3    train
# 4    train

# %% [markdown]
# to check the maximum wingspan for a bird

# %%
birds.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0
# count    342.000000    342.000000
# mean    5682.184211   5682.184211
# std     8417.167829   8417.167829
# min     3006.000000   3006.000000
# 25%     3091.250000   3091.250000
# 50%     3176.500000   3176.500000
# 75%     4334.750000   4334.750000
# max    40017.000000  40017.000000

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  342 non-null    int64
#  1   Unnamed: 0    342 non-null    int64
#  2   filepaths     342 non-null    object
#  3   labels        342 non-null    object
#  4   data set      342 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 13.5+ KB

# %%
wingspan = birds['labels']
wingspan.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 wingspan = birds['labels']
# ----> 2 wingspan.plot()
#
# File ~/miniconda3/envs/datascience/lib/python3.8/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/miniconda3/envs/datascience/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
import matplotlib.pyplot as plt
plt.title('Max Wingspan in Centimeter')
plt.ylabel('wingspan (CM)')
plt.xlabel('Birds')
plt.xticks(rotation=45)
x=birds['Name']
y=birds['MaxWingspan']

plt.plot(x,y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/datascience/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/miniconda3/envs/datascience/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/datascience/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.title('Max Wingspan in Centimeter')
plt.ylabel('wingspan (CM)')
plt.tick_params(axis='both', width='2', labelbottom=False, bottom=False)

for i in range(len(birds)):
    x=birds['Name'][i]
    y=birds['MaxWingspan'][i]
    plt.plot(x, y, 'bo' )

    if birds['MaxWingspan' ][i] > 500:
        plt.text(x, y * (1 - 0.05),birds['Name'][i], fontsize=12)


plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('Max Wingspan in Centimeter')
plt.ylabel('Wingspan (CM)')
plt.xlabel('Birds')
plt.tick_params(axis='both', width=2, labelbottom=False, bottom=False)

for i in range(len(birds)):  
    x = birds['Name'][i]
    y = birds['MaxWingspan'][i]
    plt.plot(x, y, 'bo')  # Added marker for better visibility

    if birds['MaxWingspan'][i] > 500:  # Fixed typo: added missing '[i]'
        plt.text(x, y * (1 - 0.05), birds['Name'][i], fontsize=12)  # Fixed typo: added [i]

plt.show()
